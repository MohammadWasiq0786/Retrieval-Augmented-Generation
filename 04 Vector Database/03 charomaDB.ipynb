# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\scl\anaconda3\lib\site-packages (0.5.23)
# Requirement already satisfied: build>=1.0.3 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (2.11.5)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\scl\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (3.15.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (4.13.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (1.30.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\scl\anaconda3\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\scl\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\scl\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\scl\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\scl\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.45.3)
# Requirement already satisfied: anyio in c:\users\scl\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in c:\users\scl\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\scl\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\scl\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\scl\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\scl\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\scl\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\scl\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\scl\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\scl\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.68.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\scl\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\scl\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\scl\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\scl\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\scl\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\scl\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\scl\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\scl\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\scl\anaconda3\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb) (0.32.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\scl\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\scl\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\scl\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\scl\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\scl\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\scl\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\scl\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\scl\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\scl\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\scl\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\scl\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\scl\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\scl\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\scl\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\scl\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\scl\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\scl\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\scl\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\scl\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
pip show chromadb
# Out:
# Name: chromadb
# Version: 1.0.7
# Summary: Chroma.
# Home-page: https://github.com/chroma-core/chroma
# Author:
# Author-email: Jeff Huber <jeff@trychroma.com>, Anton Troynikov <anton@trychroma.com>
# License:
# Location: c:\users\scl\anaconda3\envs\assignment_grader\lib\site-packages
# Requires: bcrypt, build, chroma-hnswlib, fastapi, grpcio, httpx, importlib-resources, jsonschema, kubernetes, mmh3, numpy, onnxruntime, opentelemetry-api, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, opentelemetry-sdk, orjson, overrides, posthog, pydantic, pypika, pyyaml, rich, tenacity, tokenizers, tqdm, typer, typing-extensions, uvicorn
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import chromadb
from chromadb.utils import embedding_functions

# %%
# Generate embeddings with vector operations
import requests
import numpy as np

EURI_API_KEY= "euri-......"

def generate_embeddings(text):
    url = "https://api.euron.one/api/v1/euri/alpha/embeddings"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {EURI_API_KEY}"
    }
    payload = {
        "input": text,
        "model": "text-embedding-3-small"
    }

    response = requests.post(url, headers=headers, json=payload)
    data = response.json()
    
    # Convert to numpy array for vector operations
    embedding = np.array(data['data'][0]['embedding'])
    
    return embedding

# %%
client = chromadb.Client()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client = chromadb.Client()
#
# File c:\Users\scl\anaconda3\envs\assignment_grader\lib\site-packages\chromadb\__init__.py:371, in Client(settings, tenant, database)
#     368 tenant = str(tenant)
#     369 database = str(database)
# --> 371 return ClientCreator(tenant=tenant, database=database, settings=settings)
#
# File c:\Users\scl\anaconda3\envs\assignment_grader\lib\site-packages\chromadb\api\client.py:63, in Client.__init__(self, tenant, database, settings)
#      57 def __init__(
#      58     self,
#      59     tenant: str = DEFAULT_TENANT,
#      60     database: str = DEFAULT_DATABASE,
#      61     settings: Settings = Settings(),
#      62 ) -> None:
# ---> 63     super().__init__(settings=settings)
#      64     self.tenant = tenant
#      65     self.database = database
#
# File c:\Users\scl\anaconda3\envs\assignment_grader\lib\site-packages\chromadb\api\shared_system_client.py:19, in SharedSystemClient.__init__(self, settings)
#      14 def __init__(
#      15     self,
#      16     settings: Settings = Settings(),
#      17 ) -> None:
#      18     self._identifier = SharedSystemClient._get_identifier_from_settings(settings)
# ---> 19     SharedSystemClient._create_system_if_not_exists(self._identifier, settings)
#
# File c:\Users\scl\anaconda3\envs\assignment_grader\lib\site-packages\chromadb\api\shared_system_client.py:38, in SharedSystemClient._create_system_if_not_exists(cls, identifier, settings)
#      36     # For now, the settings must match
#      37     if previous_system.settings != settings:
# ---> 38         raise ValueError(
#      39             f"An instance of Chroma already exists for {identifier} with different settings"
#      40         )
#      42 return cls._identifier_to_system[identifier]
#
# ValueError: An instance of Chroma already exists for ephemeral with different settings

# %%
collection = client.create_collection(name='sudhanshu_journey')

# %%
collection
# Out:
# Collection(name=sudhanshu_journey)

# %%
texts = [
    "Sudhanshu Kumar was born in Jamshedpur, Jharkhand, India, to a modest family.",
    "His early life was marked by financial hardship and limited resources.",
    "He believed education could transform his life and pursued it relentlessly.",
    "Sudhanshu earned a Computer Science and Engineering degree.",
    "He worked at Wipro, Deloitte, Verizon Labs, and Ernst & Young.",
    "He gained expertise in SAP WebDynpro, Fiori UI5 HANA, Java, Big Data, and Data Analytics.",
    "Sudhanshu remained committed to making education accessible for everyone.",
    "His teaching empowered countless students to build their careers.",
    "Many students credit him with changing their lives through affordable learning.",
    "His journey is a testament to triumph over adversity and the power of knowledge."
]

# %%
embeddings = [generate_embeddings(i).tolist() for i in texts]

# %%
len(embeddings[0])
# Out:
# 1536

# %%
collection.add(
    documents=texts,
    embeddings=embeddings,
    ids=[f"rec_{i}" for i in range(len(texts))]
)

# %%
collection.count()
# Out:
# 10

# %%
collection.get()
# Out:
# {'ids': ['rec_0',
#   'rec_1',
#   'rec_2',
#   'rec_3',
#   'rec_4',
#   'rec_5',
#   'rec_6',
#   'rec_7',
#   'rec_8',
#   'rec_9'],
#  'embeddings': None,
#  'documents': ['Sudhanshu Kumar was born in Jamshedpur, Jharkhand, India, to a modest family.',
#   'His early life was marked by financial hardship and limited resources.',
#   'He believed education could transform his life and pursued it relentlessly.',
#   'Sudhanshu earned a Computer Science and Engineering degree.',
#   'He worked at Wipro, Deloitte, Verizon Labs, and Ernst & Young.',
#   'He gained expertise in SAP WebDynpro, Fiori UI5 HANA, Java, Big Data, and Data Analytics.',
#   'Sudhanshu remained committed to making education accessible for everyone.',
#   'His teaching empowered countless students to build their careers.',
#   'Many students credit him with changing their lives through affordable learning.',
#   'His journey is a testament to triumph over adversity and the power of knowledge.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None, None, None, None, None, None, None, None, None]}

# %%
query= "sudhanshu worked at wipro"

# %%
query_emb = generate_embeddings(query).tolist()

# %%
query_emb
# Out:
# [-0.057407707,
#  -0.015191598,
#  0.04691827,
#  -0.012575698,
#  -0.011367862,
#  -0.030331524,
#  -0.0034297358,
#  0.07394278,
#  -0.0044857846,
#  -0.048029218,
#  0.0061263735,
#  -0.020048775,
#  -0.06071472,
#  -0.023446217,
#  0.052162986,
#  0.008144815,
#  0.009152421,
#  -0.049786072,
#  -0.058596164,
#  0.00987583,
#  0.030641556,
#  0.07006737,
#  0.0026578838,
#  0.004227424,
#  0.021560185,
#  -0.038909093,
#  -0.04821007,
#  -0.0010156798,
#  0.011471206,
#  -0.02348497,
#  -0.03854739,
#  -0.018576121,
#  0.03201087,
#  0.021573102,
#  0.010773634,
#  0.008002717,
#  0.01661258,
#  0.042241942,
#  -0.0022057528,
#  0.0019102531,
#  -0.027799591,
#  -0.020914283,
#  0.02256779,
#  -0.004340457,
#  -0.022012316,
#  0.044567186,
#  0.003723621,
#  -0.0047086203,
#  0.0067238323,
#  -0.026972838,
#  0.027386215,
#  -0.008028553,
#  0.011432453,
#  0.012504648,
#  0.00038855,
#  -0.036558013,
#  -0.025474347,
#  -0.007996257,
#  0.0007892106,
#  0.028703853,
#  -0.04921768,
#  0.030331524,
#  -0.049579382,
#  0.026378607,
#  -0.03082241,
#  -0.03172667,
#  -0.012814681,
#  -0.007628094,
#  0.0029469247,
#  0.020849694,
#  -0.00497344,
#  -0.0023930643,
#  -0.014726549,
#  -0.0039658337,
#  0.0013951467,
#  0.015876254,
#  -0.0098047815,
#  0.010579863,
#  0.008764881,
#  0.02728287,
#  -0.032295063,
#  -0.030202344,
#  0.016715925,
#  0.02976313,
#  -0.0142615,
#  0.006533291,
#  -0.0010067986,
#  -0.0038689487,
#  0.00021415664,
#  0.0097401915,
#  -0.02655946,
#  0.012788845,
#  -0.035085358,
#  -0.048571777,
#  -0.015462876,
#  0.010650912,
#  0.033483524,
#  -0.0052640955,
#  0.0039690635,
#  -0.02937559,
#  0.018537367,
#  0.052628037,
#  -0.014674877,
#  0.0026223592,
#  0.0068400945,
#  -0.021573102,
#  -0.05425571,
#  -0.012123567,
#  -0.02152143,
#  -0.015656646,
#  0.04415381,
#  -0.014636123,
#  0.011212846,
#  -0.010941568,
#  0.047590006,
#  -0.023769166,
#  0.023007004,
#  -0.009494749,
#  0.009359109,
#  0.0015356303,
#  -0.0014209828,
#  -0.016031269,
#  -0.027592903,
#  -0.030796573,
#  0.017839793,
#  0.043172043,
#  0.0134089105,
#  0.017968973,
#  0.037694797,
#  0.05301558,
#  -0.012814681,
#  -0.003978752,
#  0.022903658,
#  0.018937826,
#  -0.021146808,
#  0.005796964,
#  0.012620911,
#  0.030925753,
#  0.0020265153,
#  0.012149403,
#  0.034568638,
#  0.02499638,
#  -0.014494024,
#  -0.011807076,
#  -0.02152143,
#  0.019842086,
#  0.04521309,
#  0.014222746,
#  -0.023213692,
#  -0.02459592,
#  -0.006614029,
#  -0.059112884,
#  0.025797296,
#  0.012465894,
#  0.007201799,
#  -0.022063987,
#  -0.03671303,
#  -0.0345428,
#  0.028109623,
#  0.0035169325,
#  0.019157432,
#  0.027799591,
#  0.01171019,
#  0.0065429797,
#  -0.019648317,
#  0.03604129,
#  -0.0005578972,
#  0.032837622,
#  0.025732707,
#  -0.01230442,
#  0.034620307,
#  0.0048830137,
#  0.03761729,
#  0.007989799,
#  0.06024967,
#  0.0011965322,
#  -0.008538815,
#  0.009837076,
#  0.009914584,
#  -0.007957504,
#  0.028910542,
#  -0.020255463,
#  0.0035556864,
#  0.037178077,
#  -0.0035556864,
#  -0.037255585,
#  0.014171074,
#  0.041751057,
#  -0.004724768,
#  -0.015592057,
#  -0.02433756,
#  0.07590632,
#  -0.0009405937,
#  -0.010960945,
#  -0.014158156,
#  -0.017762285,
#  -0.026171919,
#  0.0033393097,
#  -0.036092963,
#  0.015915008,
#  -0.029143065,
#  0.03552457,
#  0.0370489,
#  -0.0036654898,
#  -0.05554751,
#  -0.008093143,
#  -0.019997103,
#  -0.024854282,
#  -0.025603527,
#  0.004611735,
#  0.00014280474,
#  0.016703008,
#  0.008803634,
#  -0.02190897,
#  -0.028703853,
#  0.023523724,
#  -0.029323919,
#  0.054204036,
#  -0.024750937,
#  -0.013144091,
#  0.00811252,
#  0.01223983,
#  0.022322347,
#  0.00706616,
#  -0.0053771283,
#  -0.002334933,
#  -0.018330678,
#  -0.009830617,
#  -0.0028758754,
#  0.03808234,
#  -0.04136352,
#  -0.0054288004,
#  -0.009333273,
#  0.007879996,
#  0.025939396,
#  0.0033877522,
#  0.01701304,
#  0.036532175,
#  0.044050466,
#  -0.029969819,
#  -0.021418087,
#  0.03480116,
#  -0.0020378185,
#  -0.018756973,
#  0.04376627,
#  0.038418207,
#  -0.03668719,
#  -0.0012611223,
#  -0.024247134,
#  -0.032036703,
#  0.014016057,
#  0.043688763,
#  0.015785826,
#  -0.011083666,
#  0.024182543,
#  -0.00412408,
#  -0.010586322,
#  0.009410782,
#  0.035576243,
#  -0.010508814,
#  -0.04516142,
#  -0.00026724164,
#  0.01387396,
#  -0.007550586,
#  -0.005154292,
#  -0.019738743,
#  0.013886877,
#  0.048830137,
#  -0.014494024,
#  -0.041647714,
#  0.034258604,
#  -0.012265665,
#  -0.018356515,
#  -0.0007092803,
#  -0.028342148,
#  0.022593627,
#  0.0027208591,
#  -0.023497889,
#  0.005606423,
#  0.047770858,
#  -0.04265532,
#  -0.025461428,
#  0.01609586,
#  -0.030254016,
#  0.011154715,
#  -0.009074913,
#  0.00346849,
#  0.024092117,
#  -0.009010322,
#  -0.020255463,
#  -0.044980563,
#  -0.008706749,
#  0.035085358,
#  -0.030874081,
#  0.020630088,
#  -0.0031245474,
#  -0.02839382,
#  0.068620555,
#  0.0077766515,
#  0.03552457,
#  0.022115659,
#  0.0060262587,
#  -0.020371726,
#  0.023007004,
#  0.033457685,
#  0.0012708107,
#  -0.039994206,
#  -0.01432609,
#  0.058131114,
#  -0.02663697,
#  0.0006717373,
#  0.041673552,
#  -0.032140046,
#  0.02367874,
#  -0.023575397,
#  -0.01838235,
#  0.00055749353,
#  -0.015811663,
#  -0.02826464,
#  -0.0046311123,
#  -0.017258482,
#  -0.03606713,
#  0.017155139,
#  0.030512376,
#  -0.0024802608,
#  0.006995111,
#  -0.015282025,
#  0.051258724,
#  -0.026998673,
#  -0.0006406533,
#  -0.01923494,
#  -0.016793434,
#  0.0030631868,
#  -0.014765304,
#  -0.011206388,
#  -0.0055708983,
#  -0.03539539,
#  -0.0014185606,
#  0.017555596,
#  0.044308826,
#  -0.04043342,
#  -0.024285888,
#  0.025616445,
#  0.00536421,
#  0.024350477,
#  0.008267537,
#  -0.018304842,
#  0.023859594,
#  -0.007079078,
#  0.024143789,
#  -0.0011206387,
#  0.0063233734,
#  -8.285703e-05,
#  -0.0057743574,
#  0.019557891,
#  0.008900519,
#  0.01714222,
#  -0.050328627,
#  -0.00075772294,
#  -0.013848123,
#  0.0077056023,
#  0.015346615,
#  -0.016793434,
#  -0.025474347,
#  -0.049682725,
#  -0.042732827,
#  0.034103587,
#  ...]

# %%
result = collection.query(query_embeddings=[query_emb],n_results=2)

# %%
print(result)
# Out:
# {'ids': [['rec_4', 'rec_3']], 'embeddings': None, 'documents': [['He worked at Wipro, Deloitte, Verizon Labs, and Ernst & Young.', 'Sudhanshu earned a Computer Science and Engineering degree.']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[0.8196437954902649, 0.8583085536956787]]}

# %%
next_sent = "sudhanshu kumar has competed his degree in computer science"

# %%
next_sent_embd = generate_embeddings(next_sent).tolist()

# %%
collection.update(ids=['rec_3'],
                  documents=[next_sent],
                  embeddings=[next_sent_embd])

# %%
collection.get()
# Out:
# {'ids': ['rec_0',
#   'rec_1',
#   'rec_2',
#   'rec_3',
#   'rec_4',
#   'rec_5',
#   'rec_6',
#   'rec_7',
#   'rec_8',
#   'rec_9'],
#  'embeddings': None,
#  'documents': ['Sudhanshu Kumar was born in Jamshedpur, Jharkhand, India, to a modest family.',
#   'His early life was marked by financial hardship and limited resources.',
#   'He believed education could transform his life and pursued it relentlessly.',
#   'sudhanshu kumar has competed his degree in computer science',
#   'He worked at Wipro, Deloitte, Verizon Labs, and Ernst & Young.',
#   'He gained expertise in SAP WebDynpro, Fiori UI5 HANA, Java, Big Data, and Data Analytics.',
#   'Sudhanshu remained committed to making education accessible for everyone.',
#   'His teaching empowered countless students to build their careers.',
#   'Many students credit him with changing their lives through affordable learning.',
#   'His journey is a testament to triumph over adversity and the power of knowledge.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None, None, None, None, None, None, None, None, None]}

# %%
collection.add(
    documents=["sudhanshu kumar is working with euron for now"],
    embeddings=[generate_embeddings("sudhanshu kumar is working with euron for now").tolist()],
    ids=["rec_10"],
    metadatas=[{'catagories':"sudh_info","year":2024}]
)

# %%
collection.get()
# Out:
# {'ids': ['rec_0',
#   'rec_1',
#   'rec_2',
#   'rec_3',
#   'rec_4',
#   'rec_5',
#   'rec_6',
#   'rec_7',
#   'rec_8',
#   'rec_9',
#   'rec_10'],
#  'embeddings': None,
#  'documents': ['Sudhanshu Kumar was born in Jamshedpur, Jharkhand, India, to a modest family.',
#   'His early life was marked by financial hardship and limited resources.',
#   'He believed education could transform his life and pursued it relentlessly.',
#   'sudhanshu kumar has competed his degree in computer science',
#   'He worked at Wipro, Deloitte, Verizon Labs, and Ernst & Young.',
#   'He gained expertise in SAP WebDynpro, Fiori UI5 HANA, Java, Big Data, and Data Analytics.',
#   'Sudhanshu remained committed to making education accessible for everyone.',
#   'His teaching empowered countless students to build their careers.',
#   'Many students credit him with changing their lives through affordable learning.',
#   'His journey is a testament to triumph over adversity and the power of knowledge.',
#   'sudhanshu kumar is working with euron for now'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   {'catagories': 'sudh_info', 'year': 2024}]}

# %%
collection.query(
    query_embeddings=generate_embeddings(["sudhanshu is working with euron"]).tolist(),
    n_results=2,
    where={'catagories':"sudh_info"}
)
# Out:
# {'ids': [['rec_10']],
#  'embeddings': None,
#  'documents': [['sudhanshu kumar is working with euron for now']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'year': 2024, 'catagories': 'sudh_info'}]],
#  'distances': [[0.14023710787296295]]}

# %%
from chromadb import PersistentClient

client = PersistentClient(path="./chroma_db")

collection = client.get_or_create_collection("oldstyle")

collection.add(
    documents=["Hello old style"],
    ids=["id2"]
)
